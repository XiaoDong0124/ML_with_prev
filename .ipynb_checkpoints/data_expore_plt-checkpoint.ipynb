# %%
import pandas as pd
import numpy as np
#df_org=pd.read_csv(filepath+"application_train_merge_clear_nomissing .csv")
df_org=pd.read_csv("application_train_merge_clear_nomissing_with_ylabel_dy.csv")

# %%
df=df_org
import matplotlib.pyplot as plt

# %%
df['simple_labelx'].value_counts().plot(kind='pie',autopct="%1.2f%%")
# Out:
# <AxesSubplot:ylabel='simple_labelx'>

# %%
df.plot(kind="scatter",x='DAYS_LAST_PHONE_CHANGE',y="PREV_ANNUITY_median")
# Out:
# <AxesSubplot:xlabel='DAYS_LAST_PHONE_CHANGE', ylabel='PREV_ANNUITY_median'>

# %%
filter=df['PREV_ANNUITY_median']>150000

# %%
i=df[filter].index

# %%
df=df.drop(i,axis=0)

# %%
df.plot(kind="scatter",x='DAYS_LAST_PHONE_CHANGE',y="PREV_ANNUITY_median")
# Out:
# <AxesSubplot:xlabel='DAYS_LAST_PHONE_CHANGE', ylabel='PREV_ANNUITY_median'>

# %%
df.plot(kind="scatter",x='DAYS_LAST_PHONE_CHANGE',y="simple_labelx")
# Out:
# <AxesSubplot:xlabel='DAYS_LAST_PHONE_CHANGE', ylabel='simple_labelx'>

# %%
df.plot(kind="scatter",x='PREV_ANNUITY_median',y="simple_labelx") #PREV_ANNUITY_median越高，違約機率就降低
# Out:
# <AxesSubplot:xlabel='PREV_ANNUITY_median', ylabel='simple_labelx'>

# %%
df.PREV_ANNUITY_median.hist()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="scatter",x='DAYS_LAST_PHONE_CHANGE',y="PREV_ANNUITY_median")

# %%
df['DAYS_BIRTH'].hist()
# Out:
# <AxesSubplot:>

# %%
kk=np.array(df['DAYS_BIRTH'])

# %%
type(kk)
# Out:
# numpy.ndarray

# %%
list=[]
for i in range(len(df['DAYS_BIRTH'])):
    list.append(abs(round(kk[i]/365,0)))

# %%
df['DAYS_BIRTH_YEARS']=list

# %%
df['DAYS_BIRTH_YEARS']
# Out:
# 0         26.0
# 1         46.0
# 2         52.0
# 3         52.0
# 4         55.0
#           ...
# 307506    26.0
# 307507    57.0
# 307508    41.0
# 307509    33.0
# 307510    46.0
# Name: DAYS_BIRTH_YEARS, Length: 307504, dtype: float64

# %%
df.DAYS_BIRTH_YEARS.hist()
# Out:
# <AxesSubplot:>

# %%
df1=df[['DAYS_BIRTH_YEARS','simple_labelx',']]

# %%
# Out:
#    Unnamed: 0.1  Unnamed: 0  SK_ID_CURR  TARGET  CNT_CHILDREN  \
# 0             0           0      100002     1.0           0.0
# 1             1           1      100003     0.0           0.0
# 2             2           2      100004     0.0           0.0
# 3             3           3      100006     0.0           0.0
# 4             4           4      100007     0.0           0.0
#
#    AMT_INCOME_TOTAL  NAME_EDUCATION_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0          202500.0                  1.0     -9461.0         -637.0
# 1          270000.0                  3.0    -16765.0        -1188.0
# 2           67500.0                  1.0    -19046.0         -225.0
# 3          135000.0                  1.0    -19005.0        -3039.0
# 4          121500.0                  1.0    -19932.0        -3038.0
#
#    DAYS_REGISTRATION  ...  PORTFOLIO_POS  YIELD_high  YIELD_low  YIELD_middle  \
# 0            -3648.0  ...       1.000000    0.000000   1.000000      0.000000
# ...

# %%
df1.plot(kind="scatter",x='DAYS_BIRTH_YEARS',y="simple_labelx")
# Out:
# <AxesSubplot:xlabel='DAYS_BIRTH_YEARS', ylabel='simple_labelx'>

# %%
df.groupby(['DAYS_BIRTH_YEARS','simple_labelx'])['SK_ID_CURR'].count().plot(kind='barh',xticks=(np.arange(0,61 , step=100)))
# Out:
# <AxesSubplot:ylabel='DAYS_BIRTH_YEARS,simple_labelx'>

# %%
plt.xticks(np.arange(0, 31, step=5))
